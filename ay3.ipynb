# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/Programacion-2026/blob/main/ay3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# como calcular las ecuaciones lineales

# %%
a = float(input("ingrese el valor de a:"))
b = float(input("ingrese el valor de b:"))

x = -b /a

print("El valor de x es:",x)
# Out:
# ingrese el valor de a:3
# ingrese el valor de b:4
# El valor de x es: -1.3333333333333333

# %% [markdown]
# Tambien podemos hacer calculos matematicos en

# %% [markdown]
# Podemos ponerle un alias a cualquier paquete que querramos, en este caso le pusimos "m" al paquete math

# %%
import math as m

# %% [markdown]
# Resolver las ecuacionse de segundo grado de la forma

# %%
a= float(input("Ingresa el valor de a"))
b= float(input("Ingresa el valor de b"))
c= float(input("Ingresa el valor de c"))

dis = b**2 - 4*a*c

if a!=0
  if dis < 0:
    print("la solución no existe en los reales")
  elif dis > 0:
    print("Hay dos soluciones reales")
    x_1 = (-b+ [dis**0.5])/2*a
    x_2 = (-b- [dis**0.5])/2*a
    print("x1 =".x_1)
    print("x2 =".x_2)
  elif dis ==0
    print("La solucion es única")
    x= -b/(2*a)
    print("x=",x)

elif b!=0

elif c!=0
