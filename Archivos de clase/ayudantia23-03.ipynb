# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/programacion-2026/blob/main/ayudantia23-03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Expresion:
    def __pow__(self, exponente):
        return Potencia(self, self._convertir(exponente))

    def _convertir(self, valor):
        return Numero(valor) if isinstance(valor, (int, float)) else valor

class Numero(Expresion):
    def __init__(self, valor):
        self.valor = str(valor)

class Variable(Expresion):
    def __init__(self, nombre):
        self.nombre = nombre

class Potencia(Expresion):
    def __init__(self, base, exponente):
        self.base = base
        self.exponente = exponente

# %%
class Numero:
  def __init__(self, valor):
    self.valor = valor

  def latex(self):
    return str(self.valor)

#Estos metodos que ya tiene python se llaman Sobrecarga de operadores
  def __add__(self, valor2)
    return Suma(self,valor2)

  def __sub__(self, valor2)
    return Resta(self,valor2)

  def __pow__(self, otro):
    return Potencia(self,valor2)

  def ecualiar(self,valor2):
