# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/programacion-2026/blob/main/ayudantia_06_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Playlist:
  def __init__(self, nombre)
    self.nombre = nombre
    self.[]

  def añadirCancion(self, titulo):
    self.canciones.append(titulo)
    print(f"{titulo} añadida a {self.nombre}.")

  def eliminarCancion(self, titulo):
    if titulo in self.canciones:
      self.canciones.remove(titulo)
      print(f"{titulo} ha sido eliminado de {self.nombre}.")
    else:
      print(f"{titulo} no está en {self.nombre}")

  def totalCanciones(self):
    return len(self.canciones)

  def mostrarPlaylist(self):
    print(f"=========== Playlist: {self.nombre} ===========")
