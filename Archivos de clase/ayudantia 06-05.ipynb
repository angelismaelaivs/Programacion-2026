# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/programacion-2026/blob/main/ayudantia%2006-05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= open('pruebaTexto.txt')
#Asi vamos a emprimir lo que hay dentro de nuestro archivo
print(a.read())


a.close
# Out:
# hola este es mi archivo de texto, este archivo es una prueba
# 2
# 3
# 4
# 5
# 6
# <function TextIOWrapper.close()>

# %%
with open('pruebaTexto.txt') as a:
  print(a.read(8))
# Out:
# hola est

# %%
print("Leyendo el archivo línea por línea:")
with open('pruebaTexto.txt', 'r') as file:
    for line in file:
        print(line.strip()) # .strip() elimina los caracteres de nueva línea y espacios en blanco al inicio/final

# %%
with open('pruebaTexto.txt') as a:
  for i in a:
    print(i)
# Out:
# hola este es mi archivo de texto, este archivo es una prueba
#
# 2
#
# 3
#
# 4
#
# 5
#
# 6

# %%
with open('pruebaTexto.txt','a') as a:
  a.write("esta es una nueva linea de texto.")

# %%
a= open('pruebaTexto.txt')
print(a.read())
# Out:
# hola este es mi archivo de texto, este archivo es una prueba
# 2
# 3
# 4
# 5
# 6
# esta es una nueva linea de texto.

# %%
with open('pruebaTexto.txt') as a:

# %%
b = open('nuevoArchivo.txt', 'x')
