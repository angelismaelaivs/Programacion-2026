# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/programacion-2026/blob/main/ayudantia20-05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def concatenar(listaArchivos = None):

  entrada = input('Intodce el nombre de tus archivos separados por ",":')
  listaArchivosentrada.split(',')

  for nombreArchivo in listaArchivos:
    try:
      with open(nombreArchivo,'r') as archivo:
        contenido = archivo.read()

        if not contenido:
          print('El archivo està vacio.')
        else:
          print(contenido)

    except FileNotFoundError:
      print(f'Error: El archivo {nombreArchivo} no existe.')

# %% [markdown]
# Tail

# %%
def tailEficiente(nombreArchivo):
  try:
    with open(nombreArchivo, 'r') as archivo:
      lista1=[]
      for linea in archivo:
      lista1.append(linea)

        if len(lista) > 10:
          lista1.pop(0)

      for indice,i in enumerate(lista1):  %aqui con enumerate enumeramos cada linea en la lista
          print(indice,i,)
  except FileNotFoundError:
    print(f'No existe un archivo de nombre {nombreArchivo}')

# %% [markdown]
# Encontrar la palabra màs larga de una archivo

# %%
def encontrarPalabra(nombreArchivo=None):

  if nombreArchivo is None:
    nombreArchivo = input("Introduce el nombre del archivo")

  if not nombreArchivo:
    print('No proporcionaste un nombre de archivo:')

  try:
    with open(nombreArchivo, 'r') as archivo:
      palabras = archivo.read().split()

    if not palabras:  #el not indica que el archivo esta vacio
      print('El archivo està vacio.')

    for i in nombres:
      len(nombres[i])

      palabraMax = max(palabras)
      longitudMax = len(palabraMax)

      palabrasLargas = set()

      for palabra in palabras:
        if len(palabra)= longitudMax:
          palabrasLargas.add(palabra)

      print(f'La longitud de la palabra màs larga es: {longitudMax}')
      print(f'Palabras encontradas con dicha longitud: ')
      for palabra in palabrasLargas:
        print(palabra)

  except FileNotFoundError:
    print(f'Error: El archivo {nombreArchivo} no existe.')
