# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/programacion-2026/blob/main/ayudantia11-05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def tailTexto('nombreArchivo'):

  try:
    with open(nombreArchivo, 'r') as archivo:
      print(f'Estas son las ultimas lineas del archivo {nombreArchivo}')

      ultimasLineas= []

      for linea in nombreArc
