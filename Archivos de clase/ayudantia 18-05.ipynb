# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/programacion-2026/blob/main/ayudantia%2018-05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def concatenar(listaArchivos = None):

  entrada = input('Intodce el nombre de tus archivos separados por ",":')
  listaArchivosentrada.split(',')

  for nombreArchivo in listaArchivos:
    try:
      with open(nombreArchivo,'r') as archivo:
        contenido = archivo.read()

        if not contenido:
          print('El archivo està vacio.')
        else:
          print(contenido)

    except FileNotFoundError:
      print(f'Error: El archivo {nombreArchivo} no existe.')
