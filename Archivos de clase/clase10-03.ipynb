# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/programacion-2026/blob/main/clase10-03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creacion de la clase Cliente

# %%
# Documentacion del archivo
# Created ...       , angelismaelaivs@ciencias.unam.mx

#from Cuenta import *
#from ...

class Cliente:

  def __init__(self, nombre, n, f)
        self.nombre = nombre
        self.fechaNac = n
        self.cuenta = f
  def informacion(self):
    print('Nombre::', self.nombre)
    print('Fecha de nacimiento::', self.fechaNac)
    print('Saldo::', self.cuenta.saldo)

# %% [markdown]
# Clase main

# %%
class main:
      pass
  cuenta1= Cuenta(3000, D, "27/12/03")
  cuenta.informacion()
  cliente1 = Cliente("Angel", cuenta1, "17/12/2003")
  cliente.informacion()
