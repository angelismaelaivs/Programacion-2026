# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/programacion-2026/blob/main/clase12-03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Esto va en Cuenta.py
#cada clase que creamos debe de tener su str
def __str__(self): #sirve para definir una representación en cadena de texto legible de un objeto
    return "Saldo::" + str(self.cantidad) + "::tipo::" + self.tipo

# %% [markdown]
# # Tarea 1
# Poner str a todas las clases que tenemos en teoria
#
# #Tarea 2
# Los print en el sistema deben de ir en Main, los unicos que deben de haber son los de "imprimirDetalles()"
#
# #Tarea 3
# Quitar validaciones en el codigo y ponerlas en menu
#
# #Resumen de la clase
# Vimos la relacion de clases,
