# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/Programacion-2026/blob/main/cla19_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Definicion Clase
# Una clase ees una definicion de un conjutno de elementos que sea va a crear apartir de ella, donde se guardan los atributos que tienen los objetos de la clase o los procesos que conllevan.

# %% [markdown]
# #Atributos de cuenta
# -Operador: Objeto . puede ser un atributo o metodo

# %%
#cuenta.py
class Cuenta:
  def__init__(self,a,b)
  self.saldo = a
  self.tipo = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2256583638.py in <cell line: 0>()
# ----> 1 class Cuenta:
#       2   def__init(self,a,b)
#       3   self.saldo = a
#       4   self.tipo = b
#       5
#
# /tmp/ipython-input-2256583638.py in Cuenta()
#       1 class Cuenta:
# ----> 2   def__init(self,a,b)
#       3   self.saldo = a
#       4   self.tipo = b
#       5
#
# NameError: name 'def__init' is not defined

# %%
#menu.py
#from cuenta import *
class Menu:
      pass
print("Probando el objeto")
cuenta1 = Cuenta (3000,"D")
print(cuenta1.saldo)
print(cuenta1.tipo)
# Out:
# Probando el objeto
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1000340166.py in <cell line: 0>()
#       4       pass
#       5 print("Probando el objeto")
# ----> 6 cuenta1 = Cuenta (3000)
#
# NameError: name 'Cuenta' is not defined
